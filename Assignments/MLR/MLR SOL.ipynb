# %%
import pandas as pd
df=pd.read_csv("D:\\STUDIES\\Data Science_EXCELR\\Assignments_NEW\\MLR\\ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Age_08_04'}>,
#         <Axes: title={'center': 'KM'}>],
#        [<Axes: title={'center': 'HP'}>,
#         <Axes: title={'center': 'Automatic'}>,
#         <Axes: title={'center': 'cc'}>],
#        [<Axes: title={'center': 'Doors'}>,
#         <Axes: title={'center': 'Cylinders'}>,
#         <Axes: title={'center': 'Gears'}>],
#        [<Axes: title={'center': 'Weight'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df.boxplot(figsize=(10, 10))
# Out:
# <Axes: >

# %%
# Discrete Variables
df['Fuel_Type'].value_counts().plot(kind='bar')
plt.show()

# %%
# label encoding
df['Fuel_Type']
# Out:
# 0       Diesel
# 1       Diesel
# 2       Diesel
# 3       Diesel
# 4       Diesel
#          ...
# 1431    Petrol
# 1432    Petrol
# 1433    Petrol
# 1434    Petrol
# 1435    Petrol
# Name: Fuel_Type, Length: 1436, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['Fuel_Type'] = LE.fit_transform(df['Fuel_Type'])
df.head()
# Out:
#    Price  Age_08_04     KM  Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986          1  90          0  2000      3          4
# 1  13750         23  72937          1  90          0  2000      3          4
# 2  13950         24  41711          1  90          0  2000      3          4
# 3  14950         26  48000          1  90          0  2000      3          4
# 4  13750         30  38500          1  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
# standadization
df.iloc[:, 0:].head()
# Out:
#    Price  Age_08_04     KM  Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986          1  90          0  2000      3          4
# 1  13750         23  72937          1  90          0  2000      3          4
# 2  13950         24  41711          1  90          0  2000      3          4
# 3  14950         26  48000          1  90          0  2000      3          4
# 4  13750         30  38500          1  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
df.iloc[:, 0:] = SS.fit_transform(df.iloc[:, 0:])
df.iloc[:, 0:].head()
# Out:
#       Price  Age_08_04        KM  Fuel_Type        HP  Automatic        cc  \
# 0  0.763763  -1.771966 -0.574695  -2.337868 -0.768042  -0.242893  0.997419
# 1  0.832715  -1.771966  0.117454  -2.337868 -0.768042  -0.242893  0.997419
# 2  0.887877  -1.718184 -0.715386  -2.337868 -0.768042  -0.242893  0.997419
# 3  1.163685  -1.610620 -0.547650  -2.337868 -0.768042  -0.242893  0.997419
# 4  0.832715  -1.395491 -0.801028  -2.337868 -0.768042  -0.242893  0.997419
#
#       Doors  Cylinders     Gears    Weight
# 0 -1.085139          0 -0.140425  1.758561
# 1 -1.085139          0 -0.140425  1.758561
# 2 -1.085139          0 -0.140425  1.758561
# 3 -1.085139          0 -0.140425  1.758561
# 4 -1.085139          0 -0.140425  1.853577

# %%
df.corr()
# Out:
#               Price  Age_08_04        KM  Fuel_Type        HP  Automatic  \
# Price      1.000000  -0.876590 -0.569960  -0.022157  0.314990   0.033081
# Age_08_04 -0.876590   1.000000  0.505672   0.080261 -0.156622   0.031717
# KM        -0.569960   0.505672  1.000000  -0.420586 -0.333538  -0.081854
# Fuel_Type -0.022157   0.080261 -0.420586   1.000000  0.409476   0.069718
# HP         0.314990  -0.156622 -0.333538   0.409476  1.000000   0.013144
# Automatic  0.033081   0.031717 -0.081854   0.069718  0.013144   1.000000
# cc         0.126389  -0.098084  0.102683  -0.277239  0.035856   0.066740
# Doors      0.185326  -0.148359 -0.036197  -0.026935  0.092424  -0.027654
# Cylinders       NaN        NaN       NaN        NaN       NaN        NaN
# Gears      0.063104  -0.005364  0.015023   0.069655  0.209477  -0.098555
# Weight     0.581198  -0.470253 -0.028598  -0.505303  0.089614   0.057249
#
#                  cc     Doors  Cylinders     Gears    Weight
# ...

# %%
Y=df["Price"]
X=df.iloc[:,1:]

# %%
X
# Out:
#       Age_08_04        KM  Fuel_Type        HP  Automatic        cc     Doors  \
# 0     -1.771966 -0.574695  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 1     -1.771966  0.117454  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 2     -1.718184 -0.715386  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 3     -1.610620 -0.547650  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 4     -1.395491 -0.801028  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# ...         ...       ...        ...       ...        ...       ...       ...
# 1431   0.702015 -1.279939   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1432   0.863362 -1.321120   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1433   0.809579 -1.374036   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1434   0.755797 -1.376703   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1435   1.078490 -1.827849   0.354336  0.567440  -0.242893  0.054555  1.014941
#
# ...

# %%
Y
# Out:
# 0       0.763763
# 1       0.832715
# 2       0.887877
# 3       1.163685
# 4       0.832715
#           ...
# 1431   -0.891089
# 1432    0.031491
# 1433   -0.615281
# 1434   -0.960042
# 1435   -1.042784
# Name: Price, Length: 1436, dtype: float64

# %%
# Data partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# Model Fitting
from sklearn.linear_model import LinearRegression
LR= LinearRegression()

# %%
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(LR.coef_)
# Out:
# [-0.62275564 -0.17513104  0.08831525  0.08532848  0.01551113 -0.00860195
#  -0.00952939  0.          0.02756126  0.3412293 ]

# %%
LR2=LinearRegression()
LR2.fit(X_train[['Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Weight']], Y_train)
print(LR2.coef_)
# Out:
# [-6.14754664e-01 -2.11021466e-01  1.13306407e-01 -1.17368433e-02
#   4.37916621e-04  2.98013756e-02  2.91734923e-01]

# %%
LR3=LinearRegression()
LR3.fit(X_train[['Age_08_04', 'Weight', 'KM', 'HP','Doors','cc', 'Gears', 'Automatic' ]], Y_train)
print(LR3.coef_)
# Out:
# [-0.61940636  0.28799979 -0.2066781   0.1132952   0.0019793  -0.01328209
#   0.03255792  0.02348262]

# %%
# Predictions
Y_pred_train = LR.predict(X_train)
Y_pred_test = LR.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mse1 = mean_squared_error(Y_train, Y_pred_train)
mse2 = mean_squared_error(Y_test, Y_pred_test)

mae1 = mean_absolute_error(Y_train, Y_pred_train)
mae2 = mean_absolute_error(Y_test, Y_pred_test)

r2_1 = r2_score(Y_train, Y_pred_train)
r2_2 = r2_score(Y_test, Y_pred_test)

# %%
print("Train_Mean squared error:", mse1)
print("Test_Mean squared error:", mse2)

print("Train_Mean absolute error:", mae1)
print("Test_Mean absolute error:", mae2)

print("Train_R-squared score:", r2_1)
print("Test_R-squared score:", r2_2)
# Out:
# Train_Mean squared error: 0.1299784734609596
# Test_Mean squared error: 0.15950838171155823
# Train_Mean absolute error: 0.266173498278774
# Test_Mean absolute error: 0.27384998114125303
# Train_R-squared score: 0.8695032279244472
# Test_R-squared score: 0.8428476112018002

# %%
# Predictions for model 2 
Y_pred2 = LR2.predict(X_test[['Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Weight']])
mse2 = mean_squared_error(Y_test,Y_pred2)
mae2 = mean_absolute_error(Y_test, Y_pred2)
r2_2 = r2_score(Y_test, Y_pred2)

print("Model 2:")
print("Mean squared error:", mse2)
print("Mean absolute error:", mae2)
print("R-squared score:", r2_2)
# Out:
# Model 2:
# Mean squared error: 0.15052365175192098
# Mean absolute error: 0.2747023114196704
# R-squared score: 0.8516996336517366

# %%
# Predictions for model 3 
Y_pred3= LR3.predict(X_test[['Age_08_04', 'Weight', 'KM', 'HP','Doors','cc', 'Gears', 'Automatic' ]])
mse3 = mean_squared_error(Y_test,Y_pred3)
mae3 = mean_absolute_error(Y_test, Y_pred3)
r2_3 = r2_score(Y_test, Y_pred3)

print("Model 3:")
print("Mean squared error:", mse3)
print("Mean absolute error:", mae3)
print("R-squared score:", r2_3)
# Out:
# Model 3:
# Mean squared error: 0.14986839281598285
# Mean absolute error: 0.27498193309458496
# R-squared score: 0.8523452141908852

# %%
# LASSO AND RIDGE REGRESSION
from sklearn.linear_model import Lasso, Ridge

lasso_model = Lasso(alpha=1.0)
lasso_model.fit(X_train, Y_train)
Y_pred_lasso = lasso_model.predict(X_test)
mse_lasso = mean_squared_error(Y_test, Y_pred_lasso)
mae_lasso = mean_absolute_error(Y_test, Y_pred_lasso)
r2_lasso = r2_score(Y_test, Y_pred_lasso)

ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, Y_train)
Y_pred_ridge = ridge_model.predict(X_test)
mse_ridge = mean_squared_error(Y_test, Y_pred_ridge)
mae_ridge = mean_absolute_error(Y_test, Y_pred_ridge)
r2_ridge = r2_score(Y_test, Y_pred_ridge)

print("Lasso Model:")
print("Mean squared error:", mse_lasso)
print("Mean absolute error:", mae_lasso)
print("R-squared score:", r2_lasso)

print("Ridge Model:")
print("Mean squared error:", mse_ridge)
print("Mean absolute error:", mae_ridge)
print("R-squared score:", r2_ridge)
# Out:
# Lasso Model:
# Mean squared error: 1.0160425104402415
# Mean absolute error: 0.7213160490301459
# R-squared score: -0.0010352178542201163
# Ridge Model:
# Mean squared error: 0.15944924446868658
# Mean absolute error: 0.273842143013012
# R-squared score: 0.8429058749675316

# %%
# For the above data , we got best values for Ridge regression model and that is the best model

# %%
# Some more VISUALIZATIONS

# %%
df['Price'].hist(bins=10)
df.plot.scatter(x='Age_08_04', y='Price')
from pandas.plotting import scatter_matrix
scatter_matrix(df[['Price', 'Age_08_04', 'KM']], figsize=(10, 10))
# Out:
# array([[<Axes: xlabel='Price', ylabel='Price'>,
#         <Axes: xlabel='Age_08_04', ylabel='Price'>,
#         <Axes: xlabel='KM', ylabel='Price'>],
#        [<Axes: xlabel='Price', ylabel='Age_08_04'>,
#         <Axes: xlabel='Age_08_04', ylabel='Age_08_04'>,
#         <Axes: xlabel='KM', ylabel='Age_08_04'>],
#        [<Axes: xlabel='Price', ylabel='KM'>,
#         <Axes: xlabel='Age_08_04', ylabel='KM'>,
#         <Axes: xlabel='KM', ylabel='KM'>]], dtype=object)

# %%
df.plot.scatter(x='HP', y='Price')
scatter_matrix(df[['Price', 'HP', 'KM']], figsize=(10, 10))
scatter_matrix(df[['Price', 'Age_08_04', 'HP', 'KM']], figsize=(10, 10))
# Out:
# array([[<Axes: xlabel='Price', ylabel='Price'>,
#         <Axes: xlabel='Age_08_04', ylabel='Price'>,
#         <Axes: xlabel='HP', ylabel='Price'>,
#         <Axes: xlabel='KM', ylabel='Price'>],
#        [<Axes: xlabel='Price', ylabel='Age_08_04'>,
#         <Axes: xlabel='Age_08_04', ylabel='Age_08_04'>,
#         <Axes: xlabel='HP', ylabel='Age_08_04'>,
#         <Axes: xlabel='KM', ylabel='Age_08_04'>],
#        [<Axes: xlabel='Price', ylabel='HP'>,
#         <Axes: xlabel='Age_08_04', ylabel='HP'>,
#         <Axes: xlabel='HP', ylabel='HP'>,
#         <Axes: xlabel='KM', ylabel='HP'>],
#        [<Axes: xlabel='Price', ylabel='KM'>,
#         <Axes: xlabel='Age_08_04', ylabel='KM'>,
#         <Axes: xlabel='HP', ylabel='KM'>,
#         <Axes: xlabel='KM', ylabel='KM'>]], dtype=object)

# %%
df['Fuel_Type'].value_counts().plot(kind='bar')
df.plot.scatter(x='HP', y='Price')
scatter_matrix(df[['Price', 'HP', 'KM']], figsize=(10, 10))
# Out:
# array([[<Axes: xlabel='Price', ylabel='Price'>,
#         <Axes: xlabel='HP', ylabel='Price'>,
#         <Axes: xlabel='KM', ylabel='Price'>],
#        [<Axes: xlabel='Price', ylabel='HP'>,
#         <Axes: xlabel='HP', ylabel='HP'>,
#         <Axes: xlabel='KM', ylabel='HP'>],
#        [<Axes: xlabel='Price', ylabel='KM'>,
#         <Axes: xlabel='HP', ylabel='KM'>,
#         <Axes: xlabel='KM', ylabel='KM'>]], dtype=object)

# %%
import matplotlib.pyplot as plt
df['Price'].plot.box()
plt.show()
import seaborn as sns
sns.regplot(x='HP', y='Price', data=df)
plt.show()
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Age_08_04'], df['KM'], df['Price'])
ax.set_xlabel('Age_08_04')
ax.set_ylabel('KM')
ax.set_zlabel('Price')
plt.show()

# %%
# INTERVIEW QUESTIONS

# %%
#1.
#Normalization scales the values between a fixed range of 0 to 1
#Normalization is useful when the features have different scales and units

#Standardization scales the values between a fixed range of -3 to +3
#Standardization is useful when the features have different scales and units

# %%
How They Are Helpful:

1.Improved Model Performance: Normalization and standardization can improve the performance and convergence of machine learning algorithms, especially those sensitive to the scale of the input features, such as gradient descent-based algorithms.
2.Equal Treatment of Features: By bringing all features to a similar scale, normalization and standardization ensure that no single feature dominates the learning process due to its larger magnitude.
3.Enhanced Interpretability: Standardization, in particular, can improve the interpretability of coefficients or feature importance in models like linear regression by ensuring that coefficients represent the change in the target variable for a standard deviation change in the feature.
4.Robustness: Normalization and standardization are robust techniques that are less affected by outliers compared to other scaling methods.
In summary, normalization and standardization are essential preprocessing steps that help to prepare data for modeling, improve algorithm performance, and ensure fair treatment of features. They are especially crucial in scenarios where features have different scales or units.
